# %% [markdown]
# # Smartphone Pendulum Analysis
#
# This notebook runs the analysis script and displays the generated tables and figures.

# %%
# For Colab, clone the repository first if needed.
# !git clone https://github.com/gracedo1/smartphone-pendulum-experiment.git
# %cd smartphone-pendulum-experiment

# %run analysis.py

# %%
import pandas as pd
trial_results = pd.read_csv('results/trial_results.csv')
group_summary = pd.read_csv('results/group_summary.csv')
display(trial_results)
display(group_summary)

# %%
from IPython.display import Image, display
for path in ['figures/representative_angle20_trial2.png', 'figures/period_vs_angle.png', 'figures/period_by_condition.png']:
    display(Image(filename=path))
